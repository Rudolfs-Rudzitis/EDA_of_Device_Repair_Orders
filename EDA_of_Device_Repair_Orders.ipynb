# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline

# %%
df = pd.read_csv("Repairs-Data.csv")
# display first 5 rows of dataset
df.head(5)
# Out:
#    Retailer ShipLocCy       ShipLocName  ShipLocLat  ShipLocLon  \
# 0  Euphoria        NO      Oasen Bergen    60,34896     5,29182
# 1  Euphoria        NO  Storo Storsenter    59,94719    10,77277
# 2  Euphoria        NO           Stovner     59,9611    10,92619
# 3  Euphoria        NO          Sandvika  59,8901103  10,5203809
# 4  Euphoria        NO          Byporten     59,9115      10,751
#
#   ProductCategory ProductManufacturer                            ProductModel  \
# 0     Heliographs               CHOAM  EarPods With Lightning Connector White
# 1     Heliographs               CHOAM  EarPods With Lightning Connector White
# 2     Heliographs               CHOAM  EarPods With Lightning Connector White
# 3     Heliographs               CHOAM  EarPods With Lightning Connector White
# 4     Heliographs               CHOAM             Earpods with remote and mic
#
#   PurchaseDate ProblemArea ProblemDescription RepairOrderType  \
# ...

# %%
# display last 5 rows of dataset
df.tail(5)
# Out:
#        Retailer ShipLocCy                ShipLocName  ShipLocLat  ShipLocLon  \
# 111998  Fremont        EE                       Võru  59,5764175  25,9723252
# 111999  Fremont        EE  Tallinn, Lasnamäe Centrum  59,4404683   24,865593
# 112000  Fremont        EE      Tallinn, Rocca keskus  59,4247966  24,6498549
# 112001  Fremont        EE      Tallinn, Rocca keskus  59,4247966  24,6498549
# 112002  Fremont        EE      Tallinn, Järve keskus  59,3930098  24,7184627
#
#        ProductCategory ProductManufacturer  \
# 111998     Heliographs           Acme Corp
# 111999     Heliographs           Acme Corp
# 112000     Heliographs           Acme Corp
# 112001     Heliographs           Acme Corp
# 112002     Heliographs    Frobozz Magic Co
#
#                                              ProductModel  \
# 111998           Soylent LED-View Cover Universe S7 Black
# 111999                     Soylent wireless Charger Black
# 112000  Wireless charger Soylent Universe S6/ Soylent ...
# ...

# %%
# Let's check the number of columns and rows this dataset has
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112003 entries, 0 to 112002
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Retailer             112003 non-null  object
#  1   ShipLocCy            112003 non-null  object
#  2   ShipLocName          112003 non-null  object
#  3   ShipLocLat           111997 non-null  object
#  4   ShipLocLon           111997 non-null  object
#  5   ProductCategory      112003 non-null  object
#  6   ProductManufacturer  111951 non-null  object
#  7   ProductModel         111920 non-null  object
#  8   PurchaseDate         70451 non-null   object
#  9   ProblemArea          47251 non-null   object
#  10  ProblemDescription   52282 non-null   object
#  11  RepairOrderType      112003 non-null  object
#  12  OrderCreatedDate     112003 non-null  object
#  13  OrderCompletedDate   112003 non-null  object
#  14  TransportPartner     111963 non-null  object
# ...

# %% [markdown]
# ##### Table above shows that this dataset contains of 16 columns and 112 003 rows.

# %%
# We have to check the types of data, because sometimes datatypes can be messed up,
# that's why it's important to convert to the right datatypes before we plot the data via a graph.

# %%
df.dtypes
# Out:
# Retailer               object
# ShipLocCy              object
# ShipLocName            object
# ShipLocLat             object
# ShipLocLon             object
# ProductCategory        object
# ProductManufacturer    object
# ProductModel           object
# PurchaseDate           object
# ProblemArea            object
# ProblemDescription     object
# RepairOrderType        object
# OrderCreatedDate       object
# OrderCompletedDate     object
# TransportPartner       object
# RepairPartner          object
# dtype: object
